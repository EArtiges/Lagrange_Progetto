# %%
import os 
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df=gpd.read_file('toponomastica_10000_geo/toponomastica_10000_geo.shp')

# %%
df.plot(figsize=(10,10),color=(0,0,0,0),edgecolor='k')

# %%
df
# Out:
#                                Text  TxtAngle  \
# 0                             CORSO        90
# 1                            MARCHE        90
# 2                             CORSO        89
# 3                          VANZETTI        86
# 4                             SACCO        89
# 5                                 E        85
# 6                               VIA       -24
# 7                          GIOVANNI        -4
# 8                           SERVAIS        -4
# 9                               VIA        86
# 10                           BIANCO        86
# 11                               C.        86
# 12                      BENTIVOGLIO        -4
# 13                           STRADA        -9
# 14                         COLLEGNO       -22
# 15                           ANTICA       -22
# 16                               DI       -22
# 17                              VIA        86
# 18                              VIA        87
# ...
