# %%
import pandas as pd

# %%
import os

# %%
os.listdir('.')
# Out:
# ['vrc_2013_lug_dic.csv',
#  'vrc_2012_0.csv',
#  'vrc_0.pdf',
#  'vrc2015_lugliodicembre.csv',
#  'street_names.txt',
#  'Untitled.ipynb',
#  'vrc_2011_0.csv',
#  'Criminality.ipynb',
#  'vrc_2013_gen_giu.csv',
#  'VRC2016Luglio-Dicembre.csv',
#  'VRC 01072017 31122017.csv',
#  'vrc2014lugliodicembre.csv',
#  'problematic_streets.txt',
#  'OpenData VRC 2016 (Gennaio - Giugno).csv',
#  '.ipynb_checkpoints',
#  'vrc2014gennaiogiugno.csv',
#  'VRC2017_gen_giu.csv',
#  'Open Data VRC 2015 (Gennaio - Giugno).csv']

# %%
df_crime=pd.read_csv('VRC 01072017 31122017.csv', sep=';')

# %%
df_crime
# Out:
#       Anno Accertamento  Mese Accertamento  Giorno Accertamento  \
# 0                  2017                  7                    1
# 1                  2017                  7                    1
# 2                  2017                  7                    1
# 3                  2017                  7                    1
# 4                  2017                  7                    1
# 5                  2017                  7                    1
# 6                  2017                  7                    2
# 7                  2017                  7                    2
# 8                  2017                  7                    2
# 9                  2017                  7                    2
# 10                 2017                  7                    2
# 11                 2017                  7                    2
# 12                 2017                  7                    2
# 13                 2017                  7                    2
# ...

# %%
df_crime.groupby('Descrizione Sanzione').count().sort_values('Via 1')['Via 1'].index.tolist()[::-1][0:5]
# Out:
# ["ART. 18 SANZIONI ED INDENNITA' DI MORA REGOLAMENTO C.O.S.A.P.",
#  'ARTT. 32 C. 2-47 VOLANTINAGGIO REGOLAMENTO GESTIONE RIFIUTI URBANI',
#  'ART. 57 RISERVE DI PARCHEGGIO REGOLAMENTO C.O.S.A.P.',
#  'ARTT. 28 C. 15 E 16 - 29 C. 2 D.L.vo 31/3/98 N. 114',
#  'ARTT. 83-80-87 DIVIETO DI CIRC. VEICOLI A MOTORE REGOLAMENTO VERDE PUBBLICO E PRIVATO']
